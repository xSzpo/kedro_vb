# %%
# %reload_kedro
# Out:
# 2021-04-19 17:18:27,301 - root - INFO - Registered hooks from 2 installed plugin(s): kedro-mlflow-0.7.0
# 2021-04-19 17:18:27,311 - kedro.framework.session.store - INFO - `read()` not implemented for `BaseSessionStore`. Assuming empty store.
# /Users/xszpo/miniconda3/envs/viabill/lib/python3.8/site-packages/kedro/framework/project/__init__.py:133: UserWarning: Found duplicate pipeline entries. The following will be overwritten: __default__
#   warn(
# 2021-04-19 17:18:27,417 - root - INFO - ** Kedro project viabill
# 2021-04-19 17:18:27,418 - root - INFO - Defined global variable `context`, `session` and `catalog`
# 2021-04-19 17:18:27,436 - root - INFO - Registered line magic `run_viz`

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = catalog.load('master_table')
# Out:
# 2021-04-19 17:18:28,149 - kedro.io.data_catalog - INFO - Loading data from `master_table` (ParquetDataSet)...

# %%
df
# Out:
#         customerID     sex  age   residentialAddress        postalAddress  \
# 0                1    male   25      28 Irvine Place      28 Irvine Place
# 1                2    male   19     72 Bertha Street     72 Bertha Street
# 2                3  female   22   63 Ladberry Street   63 Ladberry Street
# 3                4   other   24    98 Linneman Close    98 Linneman Close
# 4                5    male   53     56 Salonica Road     56 Salonica Road
# ...            ...     ...  ...                  ...                  ...
# 499995      499996    male   68     95 Argyle Parade     95 Argyle Parade
# 499996      499997  female   22      34 Bearke Place      34 Bearke Place
# 499997      499998    male   27  95 Glenhurst Street  95 Glenhurst Street
# 499998      499999    male   55     34 Kiandra Close     34 Kiandra Close
# 499999      500000  female   42     46 Altola Street     46 Altola Street
#
#          income residentialAddress_clean postalAddress_clean  same_address  \
# 0           NaN             Irvine Place        Irvine Place             1
# 1       43200.0            Bertha Street       Bertha Street             1
# 2       70200.0          Ladberry Street     Ladberry Street             1
# 3       93900.0           Linneman Close      Linneman Close             1
# 4       77000.0            Salonica Road       Salonica Road             1
# ...         ...                      ...                 ...           ...
# 499995  40500.0            Argyle Parade       Argyle Parade             1
# 499996  44900.0             Bearke Place        Bearke Place             1
# 499997  48700.0         Glenhurst Street    Glenhurst Street             1
# 499998   7600.0            Kiandra Close       Kiandra Close             1
# 499999  84700.0            Altola Street       Altola Street             1
#
#         transactionID  ...  late_lst_12_sum  price_lst_12_sum  \
# 0           1697842.0  ...              1.0             358.0
# 1           1834257.0  ...              2.0             599.0
# 2           1974624.0  ...              1.0             781.0
# 3           1536291.0  ...              NaN               NaN
# 4            661121.0  ...              2.0             289.0
# ...               ...  ...              ...               ...
# 499995       665043.0  ...              0.0             173.0
# 499996      1756533.0  ...              0.0             181.0
# 499997      1628579.0  ...              0.0             354.0
# 499998      1722718.0  ...              0.0             664.0
# 499999      1591096.0  ...              0.0              20.0
#
#         late_payment_first_lst_12_sum  default_lst_12_avg  \
# 0                                 1.0               0.000
# 1                                 2.0               0.000
# 2                                 4.0               0.125
# 3                                 NaN                 NaN
# 4                                10.0               0.500
# ...                               ...                 ...
# 499995                            0.0               0.000
# 499996                            0.0               0.000
# 499997                            0.0               0.000
# 499998                            0.0               0.000
# 499999                            0.0               0.000
#
#         defualted_payment_lst_12_avg  money_lost_lst_12_avg  late_lst_12_avg  \
# 0                               0.00                  0.000         0.333333
# 1                               0.00                  0.000         0.333333
# 2                               0.25                  4.125         0.125000
# 3                                NaN                    NaN              NaN
# 4                               1.75                 24.250         0.500000
# ...                              ...                    ...              ...
# 499995                          0.00                  0.000         0.000000
# 499996                          0.00                  0.000         0.000000
# 499997                          0.00                  0.000         0.000000
# 499998                          0.00                  0.000         0.000000
# 499999                          0.00                  0.000         0.000000
#
#         price_lst_12_avg  late_payment_first_lst_12_avg  geo_risk_rank
# 0             119.333333                       0.333333              4
# 1              99.833333                       0.333333              2
# 2              97.625000                       0.500000              1
# 3                    NaN                            NaN              3
# 4              72.250000                       2.500000              4
# ...                  ...                            ...            ...
# 499995        173.000000                       0.000000              4
# 499996         90.500000                       0.000000              2
# 499997         88.500000                       0.000000              0
# 499998        132.800000                       0.000000              1
# 499999         20.000000                       0.000000              1
#
# [490496 rows x 98 columns]

# %% [markdown]
# # Default rate vs #clients transactions

# %%
df['rank'].value_counts().sort_index()
# Out:
# 1.0     37721
# 2.0     74977
# 3.0     98478
# 4.0     98204
# 5.0     77503
# 6.0     50779
# 7.0     28516
# 8.0     14358
# 9.0      6283
# 10.0     2409
# 11.0      852
# 12.0      298
# 13.0       79
# 14.0       31
# 15.0        6
# 16.0        2
# Name: rank, dtype: int64

# %%
df.loc[df['rank']>9,'rank'] = 10
# Out:
# 2021-04-19 17:18:30,856 - numexpr.utils - INFO - NumExpr defaulting to 4 threads.

# %%
# %matplotlib inline
from matplotlib.ticker import FuncFormatter

sns.set(style="whitegrid")

fig, ax1 = plt.subplots(figsize=(10,6))
ax2 = ax1.twinx()

df.assign(paymentStatus1=lambda x: x['paymentStatus1']==2).groupby('rank')['paymentStatus1'].mean().sort_index().plot(label='paymentStatus1 default %', ax=ax1)
df.assign(paymentStatus2=lambda x: x['paymentStatus2']==2).groupby('rank')['paymentStatus2'].mean().sort_index().plot(label='paymentStatus2 default %', ax=ax1)
df.assign(paymentStatus3=lambda x: x['paymentStatus3']==2).groupby('rank')['paymentStatus3'].mean().sort_index().plot(label='paymentStatus3 default %', ax=ax1)
df.assign(paymentStatus4=lambda x: x['paymentStatus4']==2).groupby('rank')['paymentStatus4'].mean().sort_index().plot(label='paymentStatus4 default %', ax=ax1)
df.groupby('rank')['default'].mean().sort_index().plot(label='default rate', ax=ax1)

df['rank'].value_counts().sort_index().plot(color='red', label='# of transactions' ,ax=ax2)

ax2.lines[0].set_linestyle("--")

ax1.legend(loc = (.05,.25), frameon = False)
ax2.legend(loc = (.05, .15), frameon = False)

ax1.set(xlabel='# of total transactions', ylabel='paymentStatus rate (default)')
ax2.set(ylabel='number of records')

plt.title('Default rate vs # of clients transactions', y=1.05, fontsize = 16)
ax1.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.2%}'.format(y))) 
ax2.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:,.0f}'.format(y))) 

plt.show()

# %%
# %matplotlib inline
from matplotlib.ticker import FuncFormatter

sns.set(style="whitegrid")

fig, ax1 = plt.subplots(figsize=(10,6))
ax2 = ax1.twinx()

df.assign(paymentStatus1=lambda x: x['paymentStatus1']==1).groupby('rank')['paymentStatus1'].mean().sort_index().plot(label='paymentStatus1 late payment %', ax=ax1)
df.assign(paymentStatus2=lambda x: x['paymentStatus2']==1).groupby('rank')['paymentStatus2'].mean().sort_index().plot(label='paymentStatus2 late payment %', ax=ax1)
df.assign(paymentStatus3=lambda x: x['paymentStatus3']==1).groupby('rank')['paymentStatus3'].mean().sort_index().plot(label='paymentStatus3 late payment %', ax=ax1)
df.assign(paymentStatus4=lambda x: x['paymentStatus4']==1).groupby('rank')['paymentStatus4'].mean().sort_index().plot(label='paymentStatus4 late payment %', ax=ax1)
df.groupby('rank')['late'].mean().sort_index().plot(label='late rate', ax=ax1)

df['rank'].value_counts().sort_index().plot(color='red', label='# of transactions' ,ax=ax2)

ax2.lines[0].set_linestyle("--")

ax1.legend(loc = (.05,.25), frameon = False)
ax2.legend(loc = (.05, .15), frameon = False)

ax1.set(xlabel='# of total transactions', ylabel='paymentStatus rate (late)')
ax2.set(ylabel='number of records')

plt.title('Late payment vs # of clients transactions', y=1.05, fontsize = 16)
ax1.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.2%}'.format(y))) 
ax2.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:,.0f}'.format(y))) 

plt.show()

# %% [markdown]
# # Default rate vs "pseudo time"

# %% [markdown]
# transaction ID is rising monotonically, I divide it into days

# %%
number_of_weeks = 52
fig, ax1 = plt.subplots(figsize=(10,6))

dates = dict([i for i in zip(range(number_of_weeks), pd.date_range(start='2020-01-01', end='2020-12-31',periods=number_of_weeks))])
div = round(df.transactionID.max()/(number_of_weeks-1),0)
df['pseudo_date'] = df.transactionID.apply(lambda x: int(round(x/div,0))).map(lambda x: dates[x])
df.set_index('pseudo_date').resample('W')[['default']].agg(default_rate=('default', 'mean')).plot(ax=ax1)
df.set_index('pseudo_date').resample('W')[['late']].agg(late_payment=('late', 'mean')).plot(ax=ax1)
# Out:
# <AxesSubplot:xlabel='pseudo_date'>

# %% [markdown]
# # Create data splits

# %%
df.default.mean()
# Out:
# 0.09094875391440502

# %%
df.late.mean()
# Out:
# 0.29439995433194155

# %%
params_ds = catalog.load('params:data_set')
# Out:
# 2021-04-19 17:18:41,488 - kedro.io.data_catalog - INFO - Loading data from `params:data_set` (MemoryDataSet)...

# %%
params_ds
# Out:
# {'oot': 50000, 'train': 0.7, 'test': 0.2, 'valid': 0.1}

# %%
df_oot = df.sort_values('customerID').iloc[-params_ds['oot']:].sort_index()
df = df.sort_values('customerID').iloc[:-params_ds['oot']]

# %%
size=df.shape[0]
train_size = int(size * params_ds['train'])
test_size = int(size * params_ds['test'])

df=df.sample(frac=1, random_state=1)
df_train = df.iloc[:train_size].sort_index()
df_test = df.iloc[train_size:(train_size+test_size)].sort_index()
df_valid = df.iloc[(train_size+test_size):].sort_index()

# %% [markdown]
# # model lightgbm - no hp, just for feature importance

# %%
import numpy as np
from category_encoders import *

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_predict
from sklearn import metrics
from sklearn.metrics import roc_auc_score

import lightgbm as lgb
from lightgbm import LGBMClassifier

import matplotlib.pyplot as plt 

import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=DeprecationWarning)

# %%
categorical_cols = ['sex', 'residentialAddress_clean',
                    'geo_risk_rank', 'shopID',
                    'same_address']
numerical_cols = ['age', 'income', 'price'] + \
    df.filter(regex='(^hist_)|(_lst_)').columns.to_list()

target_def = 'default'
target_late = 'late'

# %%
lgb_params = {"seed": 42,
              "objective": "binary", 
              "learning_rate": 0.1,
              "metric":"auc"
              }

# %%
transformer = make_pipeline(
    ColumnTransformer([
        ('num','passthrough', numerical_cols),
        ('cat', OrdinalEncoder(), categorical_cols),    
    ]),
)

# %%
d_train = lgb.Dataset(
    transformer.fit_transform(df_train, df_train['default']), 
    label=df_train['default'], 
    feature_name=transformer.named_steps['columntransformer'].get_feature_names(),
    params={'verbose': -1})

d_valid = lgb.Dataset(
    transformer.transform(df_valid), 
    label=df_valid['default'], 
    feature_name=transformer.named_steps['columntransformer'].get_feature_names(),
    params={'verbose': -1})

d_test = lgb.Dataset(
    transformer.transform(df_test), 
    label=df_test['default'], 
    feature_name=transformer.named_steps['columntransformer'].get_feature_names(),
    params={'verbose': -1})

# %%
classifier = make_pipeline(
    ColumnTransformer([
        ('num','passthrough', numerical_cols),
        ('cat', OrdinalEncoder(), categorical_cols),       
    ]),
    LGBMClassifier(n_estimators=500, random_state=1, metric= "auc", importance_type='gain')
)

# %%
# %%time
results=[]

for i in range(1,11): 
    _tmp_target = df.loc[df['rank']==i].reset_index(drop=True)[target_column].values.reshape(-1,)
    oof_pred = cross_val_predict(classifier, 
                                 df.loc[df['rank']==i].reset_index(drop=True), 
                                 _tmp_target, 
                                 cv=5,
                                 method="predict_proba")
    _tmp_roc_score = roc_auc_score(_tmp_target, oof_pred[:,1])
    results += [(i, _tmp_roc_score)]
    print("#{}, Cross validation AUC {:.4f}".format(i, _tmp_roc_score))

    
_tmp_target = df[target_column].values.reshape(-1,)
oof_pred = cross_val_predict(classifier, 
                             df, 
                             _tmp_target, 
                             cv=5,
                             method="predict_proba")
_tmp_roc_score = roc_auc_score(_tmp_target, oof_pred[:,1])
results += [(i, _tmp_roc_score)]
print("#ALL, Cross validation AUC {:.4f}".format(_tmp_roc_score))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# NameError: name 'target_column' is not defined

# %%
model = lgb.train(
    lgb_params,
    d_train,
    valid_sets=[d_train, d_valid],
    valid_names=['train', 'valid'],
)
# Out:
# [LightGBM] [Info] Number of positive: 28135, number of negative: 280212
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.098521 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 7663
# [LightGBM] [Info] Number of data points in the train set: 308347, number of used features: 75
# [1]	train's auc: 0.664556	valid's auc: 0.665479
# [2]	train's auc: 0.667269	valid's auc: 0.668316
# [3]	train's auc: 0.667925	valid's auc: 0.669386
# [4]	train's auc: 0.66815	valid's auc: 0.669347
# [5]	train's auc: 0.668526	valid's auc: 0.669342
# [6]	train's auc: 0.66899	valid's auc: 0.669311
# [7]	train's auc: 0.669615	valid's auc: 0.670201
# [8]	train's auc: 0.669921	valid's auc: 0.670281
# [9]	train's auc: 0.670107	valid's auc: 0.670216
# [10]	train's auc: 0.67021	valid's auc: 0.670301
# [11]	train's auc: 0.670625	valid's auc: 0.670241
# [12]	train's auc: 0.670959	valid's auc: 0.670325
# [13]	train's auc: 0.671682	valid's auc: 0.67011
# [14]	train's auc: 0.671725	valid's auc: 0.670033
# [15]	train's auc: 0.671902	valid's auc: 0.67005
# [16]	train's auc: 0.672173	valid's auc: 0.670053
# [17]	train's auc: 0.672312	valid's auc: 0.669979
# [18]	train's auc: 0.672435	valid's auc: 0.669827
# [19]	train's auc: 0.672555	valid's auc: 0.669783
# [20]	train's auc: 0.672571	valid's auc: 0.669754
# [21]	train's auc: 0.673544	valid's auc: 0.669856
# [22]	train's auc: 0.673872	valid's auc: 0.669749
# [23]	train's auc: 0.674349	valid's auc: 0.669701
# [24]	train's auc: 0.674839	valid's auc: 0.669645
# [25]	train's auc: 0.675567	valid's auc: 0.669668
# [26]	train's auc: 0.675623	valid's auc: 0.669685
# [27]	train's auc: 0.67613	valid's auc: 0.669553
# [28]	train's auc: 0.676373	valid's auc: 0.669618
# [29]	train's auc: 0.677322	valid's auc: 0.669677
# [30]	train's auc: 0.677469	valid's auc: 0.669691
# [31]	train's auc: 0.677842	valid's auc: 0.669802
# [32]	train's auc: 0.678995	valid's auc: 0.669516
# [33]	train's auc: 0.679245	valid's auc: 0.669445
# [34]	train's auc: 0.679447	valid's auc: 0.669384
# [35]	train's auc: 0.680297	valid's auc: 0.669273
# [36]	train's auc: 0.681136	valid's auc: 0.669031
# [37]	train's auc: 0.681802	valid's auc: 0.668923
# [38]	train's auc: 0.682912	valid's auc: 0.669122
# [39]	train's auc: 0.684107	valid's auc: 0.66941
# [40]	train's auc: 0.684395	valid's auc: 0.669599
# [41]	train's auc: 0.684425	valid's auc: 0.669582
# [42]	train's auc: 0.685039	valid's auc: 0.669481
# [43]	train's auc: 0.685251	valid's auc: 0.669481
# [44]	train's auc: 0.685322	valid's auc: 0.669425
# [45]	train's auc: 0.686282	valid's auc: 0.669464
# [46]	train's auc: 0.686307	valid's auc: 0.669412
# [47]	train's auc: 0.686317	valid's auc: 0.669415
# [48]	train's auc: 0.687124	valid's auc: 0.669413
# [49]	train's auc: 0.687884	valid's auc: 0.669445
# [50]	train's auc: 0.687988	valid's auc: 0.669428
# [51]	train's auc: 0.689059	valid's auc: 0.669085
# [52]	train's auc: 0.689868	valid's auc: 0.669069
# [53]	train's auc: 0.690654	valid's auc: 0.669081
# [54]	train's auc: 0.690816	valid's auc: 0.669015
# [55]	train's auc: 0.690854	valid's auc: 0.66902
# [56]	train's auc: 0.691267	valid's auc: 0.668846
# [57]	train's auc: 0.691745	valid's auc: 0.668908
# [58]	train's auc: 0.692103	valid's auc: 0.66926
# [59]	train's auc: 0.692923	valid's auc: 0.669312
# [60]	train's auc: 0.693386	valid's auc: 0.669201
# [61]	train's auc: 0.694239	valid's auc: 0.669557
# [62]	train's auc: 0.69425	valid's auc: 0.669554
# [63]	train's auc: 0.694775	valid's auc: 0.669367
# [64]	train's auc: 0.695368	valid's auc: 0.669127
# [65]	train's auc: 0.696057	valid's auc: 0.669023
# [66]	train's auc: 0.696387	valid's auc: 0.669097
# [67]	train's auc: 0.696461	valid's auc: 0.669111
# [68]	train's auc: 0.697043	valid's auc: 0.669328
# [69]	train's auc: 0.697224	valid's auc: 0.669409
# [70]	train's auc: 0.697858	valid's auc: 0.669453
# [71]	train's auc: 0.698055	valid's auc: 0.669248
# [72]	train's auc: 0.698255	valid's auc: 0.669264
# [73]	train's auc: 0.69887	valid's auc: 0.669316
# [74]	train's auc: 0.699021	valid's auc: 0.669485
# [75]	train's auc: 0.699417	valid's auc: 0.669191
# [76]	train's auc: 0.699839	valid's auc: 0.669177
# [77]	train's auc: 0.700025	valid's auc: 0.669158
# [78]	train's auc: 0.700157	valid's auc: 0.669116
# [79]	train's auc: 0.700779	valid's auc: 0.669152
# [80]	train's auc: 0.701205	valid's auc: 0.669013
# [81]	train's auc: 0.7013	valid's auc: 0.669012
# [82]	train's auc: 0.701873	valid's auc: 0.668727
# [83]	train's auc: 0.702033	valid's auc: 0.66871
# [84]	train's auc: 0.702575	valid's auc: 0.668681
# [85]	train's auc: 0.702754	valid's auc: 0.668869
# [86]	train's auc: 0.702756	valid's auc: 0.668875
# [87]	train's auc: 0.703147	valid's auc: 0.668721
# [88]	train's auc: 0.703639	valid's auc: 0.668425
# [89]	train's auc: 0.70399	valid's auc: 0.668419
# [90]	train's auc: 0.704199	valid's auc: 0.668482
# [91]	train's auc: 0.704619	valid's auc: 0.668488
# [92]	train's auc: 0.704626	valid's auc: 0.668484
# [93]	train's auc: 0.705199	valid's auc: 0.66814
# [94]	train's auc: 0.705695	valid's auc: 0.668303
# [95]	train's auc: 0.706235	valid's auc: 0.668362
# [96]	train's auc: 0.706295	valid's auc: 0.668374
# [97]	train's auc: 0.706532	valid's auc: 0.668208
# [98]	train's auc: 0.707233	valid's auc: 0.667831
# [99]	train's auc: 0.707733	valid's auc: 0.66728
# [100]	train's auc: 0.707824	valid's auc: 0.667317

# %%
fig, ax2 = plt.subplots(figsize=(10,10))
lgb.plot_importance(model, max_num_features=15, ax=ax2, importance_type = 'gain')
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>
